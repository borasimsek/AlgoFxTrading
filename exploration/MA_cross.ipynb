# %%
import pandas as pd
from plotting import CandlePlot
pd.set_option('display.max_columns', None)

# %%
df_ma_res = pd.read_pickle('../data/ma_res.pkl')
df_ma_trades = pd.read_pickle('../data/ma_trades.pkl')

# %%
df_ma_res.granularity.unique()
# Out:
# array(['H1', 'H4'], dtype=object)

# %%
df_ma_res_h1 = df_ma_res[df_ma_res.granularity == 'H1'].copy()
df_ma_trades_h1 = df_ma_trades[df_ma_trades.granularity == 'H1'].copy()

# %%
df_ma_trades_h1.shape
# Out:
# (16476, 32)

# %%
df_ma_trades_h1.columns
# Out:
# Index(['time', 'volume', 'mid_o', 'mid_h', 'mid_l', 'mid_c', 'bid_o', 'bid_h',
#        'bid_l', 'bid_c', 'ask_o', 'ask_h', 'ask_l', 'ask_c', 'MA_40', 'MA_10',
#        'MA_80', 'MA_20', 'MA_150', 'MA_120', 'MA_30', 'DELTA', 'DELTA_PREV',
#        'TRADE', 'DIFF', 'GAIN', 'granularity', 'pair', 'GAIN_C', 'ma_l',
#        'ma_s', 'cross'],
#       dtype='object')

# %%
df_cross_summary = df_ma_res_h1[['pair_name', 'num_trades', 'total_gain' , 'cross']].copy()

# %%
df_cross_summary
# Out:
#     pair_name  num_trades  total_gain         cross
# 0     EUR_USD         215        -161   MA_20_MA_10
# 1     EUR_USD         108         265   MA_40_MA_10
# 2     EUR_USD         108        -623   MA_40_MA_20
# 3     EUR_USD         122         -69   MA_40_MA_30
# 4     EUR_USD          78        -363   MA_80_MA_10
# ..        ...         ...         ...           ...
# 235   CAD_JPY          37        -152  MA_120_MA_40
# 236   CAD_JPY          51        -159  MA_150_MA_10
# 237   CAD_JPY          35        -151  MA_150_MA_20
# 238   CAD_JPY          33        -167  MA_150_MA_30
# 239   CAD_JPY          25          88  MA_150_MA_40
#
# [240 rows x 4 columns]

# %%
df_cross_gr = df_cross_summary.groupby("cross", as_index=False).sum(numeric_only=True)
df_cross_gr.sort_values('total_gain', ascending=False, inplace=True)
df_cross_gr.head(10)
# Out:
#            cross  num_trades  total_gain
# 7   MA_150_MA_40         416        9907
# 6   MA_150_MA_30         470        8758
# 2   MA_120_MA_30         559        7468
# 3   MA_120_MA_40         496        6797
# 4   MA_150_MA_10         742        6428
# 5   MA_150_MA_20         570        6223
# 0   MA_120_MA_10         838        4615
# 14   MA_80_MA_30         772        3713
# 12   MA_80_MA_10        1079        3665
# 15   MA_80_MA_40         746        3613

# %%
total_pairs = len(df_ma_res_h1.pair_name.unique())
total_pairs
# Out:
# 15

# %%
temp = df_ma_res_h1[df_ma_res_h1.cross == "MA_10_MA_40"]

# %%
temp[temp.total_gain > 0].shape[0]
# Out:
# 0

# %%
for c in df_ma_res_h1.cross.unique():
    temp = df_ma_res_h1[df_ma_res_h1.cross == c]
    pg = temp[temp.total_gain > 0].shape[0]
    print(f"{c}: {pg} positive trades out of {temp.shape[0]} ({pg/temp.shape[0]*100:.2f}%)")
# Out:
# MA_20_MA_10: 8 positive trades out of 15 (53.33%)
# MA_40_MA_10: 8 positive trades out of 15 (53.33%)
# MA_40_MA_20: 6 positive trades out of 15 (40.00%)
# MA_40_MA_30: 9 positive trades out of 15 (60.00%)
# MA_80_MA_10: 9 positive trades out of 15 (60.00%)
# MA_80_MA_20: 7 positive trades out of 15 (46.67%)
# MA_80_MA_30: 9 positive trades out of 15 (60.00%)
# MA_80_MA_40: 8 positive trades out of 15 (53.33%)
# MA_120_MA_10: 11 positive trades out of 15 (73.33%)
# MA_120_MA_20: 7 positive trades out of 15 (46.67%)
# MA_120_MA_30: 9 positive trades out of 15 (60.00%)
# MA_120_MA_40: 7 positive trades out of 15 (46.67%)
# MA_150_MA_10: 10 positive trades out of 15 (66.67%)
# MA_150_MA_20: 8 positive trades out of 15 (53.33%)
# MA_150_MA_30: 10 positive trades out of 15 (66.67%)
# MA_150_MA_40: 10 positive trades out of 15 (66.67%)

# %%
cross = "MA_40_MA_10"
df_MA_40_MA_10 = df_ma_res_h1[df_ma_res_h1.cross == cross].copy()
df_MA_40_MA_10.sort_values(by= 'total_gain', ascending=False, inplace=True)
df_MA_40_MA_10.head(15)
# Out:
#     pair_name  num_trades  total_gain  mean_gain  min_gain  max_gain   ma_l  \
# 65    EUR_CAD          98        1507         15       -82       238  MA_40
# 161   GBP_CAD          94        1355         14       -90       359  MA_40
# 49    EUR_AUD         104         945          9      -111       292  MA_40
# 113   GBP_USD         112         457          4      -119       332  MA_40
# 129   GBP_JPY         109         283          2      -316      1082  MA_40
# 1     EUR_USD         108         265          2      -148       186  MA_40
# 33    EUR_JPY         111          63          0      -191       656  MA_40
# 193   AUD_JPY         115           4          0      -121       554  MA_40
# 81    USD_JPY         119         -61          0      -232       775  MA_40
# 225   CAD_JPY         129         -85          0      -136       544  MA_40
# 17    EUR_GBP         129        -339         -2       -54       139  MA_40
# 209   AUD_CAD         127        -373         -2       -67       143  MA_40
# 177   AUD_USD         121        -401         -3       -79       191  MA_40
# 97    USD_CAD         118        -440         -3      -134       267  MA_40
# 145   GBP_AUD         117        -652         -5      -170       321  MA_40
#
#       ma_s        cross granularity
# 65   MA_10  MA_40_MA_10          H1
# 161  MA_10  MA_40_MA_10          H1
# 49   MA_10  MA_40_MA_10          H1
# 113  MA_10  MA_40_MA_10          H1
# 129  MA_10  MA_40_MA_10          H1
# 1    MA_10  MA_40_MA_10          H1
# 33   MA_10  MA_40_MA_10          H1
# 193  MA_10  MA_40_MA_10          H1
# 81   MA_10  MA_40_MA_10          H1
# 225  MA_10  MA_40_MA_10          H1
# 17   MA_10  MA_40_MA_10          H1
# 209  MA_10  MA_40_MA_10          H1
# 177  MA_10  MA_40_MA_10          H1
# 97   MA_10  MA_40_MA_10          H1
# 145  MA_10  MA_40_MA_10          H1

# %%
df_gains = df_ma_trades_h1[(df_ma_trades_h1.cross==cross)&
                           (df_ma_trades_h1.pair=="EUR_AUD")].copy()

# %%
df_gains
# Out:
# Empty DataFrame
# Columns: [time, volume, mid_o, mid_h, mid_l, mid_c, bid_o, bid_h, bid_l, bid_c, ask_o, ask_h, ask_l, ask_c, MA_40, MA_10, MA_80, MA_20, MA_150, MA_120, MA_30, DELTA, DELTA_PREV, TRADE, DIFF, GAIN, granularity, pair, GAIN_C, ma_l, ma_s, cross]
# Index: []

# %%
cp = CandlePlot(df_gains, candles=False)
cp.show_plot(line_traces=['GAIN_C'])

# %%
for curr in df_MA_40_MA_10[df_MA_40_MA_10.total_gain > 0].pair_name.unique():
    temp_gains = df_ma_trades_h1[(df_ma_trades_h1.cross==cross)&
                           (df_ma_trades_h1.pair==curr)].copy()
    print(curr, int(temp_gains.GAIN.sum()))
    cp = CandlePlot(temp_gains, candles=False)
    cp.show_plot(line_traces=['GAIN_C'])
# Out:
# EUR_CAD 0
# GBP_CAD 0
# EUR_AUD 0
# GBP_USD 0
# GBP_JPY 0
# EUR_USD 0
# EUR_JPY 0
# AUD_JPY 0

# %%
import pandas as pd
from plotting import CandlePlot
pd.set_option("display.max_columns", None)

# %%
df_ma_res = pd.read_pickle("../data/ma_res.pkl")
df_ma_trades = pd.read_pickle("../data/ma_trades.pkl")

# %%
df_ma_res.granularity.unique()
# Out:
# array(['H1', 'H4'], dtype=object)

# %%
df_ma_res_h1 = df_ma_res[df_ma_res.granularity == "H1"].copy()
df_ma_trades_h1 = df_ma_trades[df_ma_trades.granularity == "H1"].copy()

# %%
df_ma_trades_h1.shape
# Out:
# (16476, 32)

# %%
df_ma_res_h1.columns
# Out:
# Index(['pair_name', 'num_trades', 'total_gain', 'mean_gain', 'min_gain',
#        'max_gain', 'ma_l', 'ma_s', 'cross', 'granularity'],
#       dtype='object')

# %%
df_cross_summary = df_ma_res_h1[['pair_name', 'num_trades', 'total_gain','cross']].copy()

# %%
df_cross_gr = df_cross_summary.groupby(by="cross", as_index=False).sum()
df_cross_gr.sort_values(by="total_gain", ascending=False, inplace=True)

# %%
df_cross_gr.head()
# Out:
#           cross                                          pair_name  \
# 7  MA_150_MA_40  EUR_USDEUR_GBPEUR_JPYEUR_AUDEUR_CADUSD_JPYUSD_...
# 6  MA_150_MA_30  EUR_USDEUR_GBPEUR_JPYEUR_AUDEUR_CADUSD_JPYUSD_...
# 2  MA_120_MA_30  EUR_USDEUR_GBPEUR_JPYEUR_AUDEUR_CADUSD_JPYUSD_...
# 3  MA_120_MA_40  EUR_USDEUR_GBPEUR_JPYEUR_AUDEUR_CADUSD_JPYUSD_...
# 4  MA_150_MA_10  EUR_USDEUR_GBPEUR_JPYEUR_AUDEUR_CADUSD_JPYUSD_...
#
#    num_trades  total_gain
# 7         416        9907
# 6         470        8758
# 2         559        7468
# 3         496        6797
# 4         742        6428

# %%
total_pairs = len(df_ma_res_h1.pair_name.unique())

# %%
total_pairs
# Out:
# 15

# %%
temp = df_ma_res_h1[df_ma_res_h1.cross == "MA_10_MA_40"]

# %%
temp[temp.total_gain > 0].shape[0]
# Out:
# 0

# %%
for c in df_ma_res_h1.cross.unique():
    temp = df_ma_res_h1[df_ma_res_h1.cross == c]
    pg = temp[temp.total_gain > 0].shape[0]
    print(f"{c} pg:{pg} perc gain:{(pg / total_pairs) * 100:.0f}%")
# Out:
# MA_20_MA_10 pg:8 perc gain:53%
# MA_40_MA_10 pg:8 perc gain:53%
# MA_40_MA_20 pg:6 perc gain:40%
# MA_40_MA_30 pg:9 perc gain:60%
# MA_80_MA_10 pg:9 perc gain:60%
# MA_80_MA_20 pg:7 perc gain:47%
# MA_80_MA_30 pg:9 perc gain:60%
# MA_80_MA_40 pg:8 perc gain:53%
# MA_120_MA_10 pg:11 perc gain:73%
# MA_120_MA_20 pg:7 perc gain:47%
# MA_120_MA_30 pg:9 perc gain:60%
# MA_120_MA_40 pg:7 perc gain:47%
# MA_150_MA_10 pg:10 perc gain:67%
# MA_150_MA_20 pg:8 perc gain:53%
# MA_150_MA_30 pg:10 perc gain:67%
# MA_150_MA_40 pg:10 perc gain:67%

# %%
cross = "MA_40_MA_20"
df_MA_40_MA_20 = df_ma_res_h1[df_ma_res_h1.cross == cross].copy()
df_MA_40_MA_20.sort_values(by="total_gain", ascending=False, inplace=True)

# %%
df_MA_40_MA_20
# Out:
#     pair_name  num_trades  total_gain  mean_gain  min_gain  max_gain   ma_l  \
# 130   GBP_JPY          99        1278         12      -298      1199  MA_40
# 50    EUR_AUD          91        1111         12      -133       302  MA_40
# 66    EUR_CAD          90         991         11       -89       178  MA_40
# 162   GBP_CAD          94         618          6      -115       400  MA_40
# 226   CAD_JPY         106         361          3      -162       497  MA_40
# 114   GBP_USD         102           4          0      -124       327  MA_40
# 194   AUD_JPY         117        -325         -2      -170       542  MA_40
# 18    EUR_GBP         105        -330         -3       -62       174  MA_40
# 178   AUD_USD         108        -427         -3       -98       180  MA_40
# 2     EUR_USD         108        -623         -5      -171       154  MA_40
# 98    USD_CAD         105        -684         -6      -151       257  MA_40
# 146   GBP_AUD         111        -883         -7      -219       311  MA_40
# 210   AUD_CAD         119        -930         -7      -159       149  MA_40
# 82    USD_JPY         106       -1098        -10      -238       745  MA_40
# 34    EUR_JPY         101       -1334        -13      -245       635  MA_40
#
#       ma_s        cross granularity
# 130  MA_20  MA_40_MA_20          H1
# 50   MA_20  MA_40_MA_20          H1
# 66   MA_20  MA_40_MA_20          H1
# 162  MA_20  MA_40_MA_20          H1
# 226  MA_20  MA_40_MA_20          H1
# 114  MA_20  MA_40_MA_20          H1
# 194  MA_20  MA_40_MA_20          H1
# 18   MA_20  MA_40_MA_20          H1
# 178  MA_20  MA_40_MA_20          H1
# 2    MA_20  MA_40_MA_20          H1
# 98   MA_20  MA_40_MA_20          H1
# 146  MA_20  MA_40_MA_20          H1
# 210  MA_20  MA_40_MA_20          H1
# 82   MA_20  MA_40_MA_20          H1
# 34   MA_20  MA_40_MA_20          H1

# %%
df_gains = df_ma_trades_h1[(df_ma_trades_h1.cross==cross)&
                           (df_ma_trades_h1.pair=="CAD_JPY")].copy()

# %%
df_gains.head(3)
# Out:
# Empty DataFrame
# Columns: [time, volume, mid_o, mid_h, mid_l, mid_c, bid_o, bid_h, bid_l, bid_c, ask_o, ask_h, ask_l, ask_c, MA_40, MA_10, MA_80, MA_20, MA_150, MA_120, MA_30, DELTA, DELTA_PREV, TRADE, DIFF, GAIN, granularity, pair, GAIN_C, ma_l, ma_s, cross]
# Index: []

# %%
cp = CandlePlot(df_gains, candles=False)
cp.show_plot(line_traces=['GAIN_C'])

# %%
for curr in df_MA_40_MA_20[df_MA_40_MA_20.total_gain > 0].pair_name.unique():
    temp_gains = df_ma_trades_h1[(df_ma_trades_h1.cross==cross)&
                           (df_ma_trades_h1.pair==curr)].copy()
    print(curr, int(temp_gains.GAIN.sum()))
    cp = CandlePlot(temp_gains, candles=False)
    cp.show_plot(line_traces=['GAIN_C'])
# Out:
# GBP_JPY 0
# EUR_AUD 0
# EUR_CAD 0
# GBP_CAD 0
# CAD_JPY 0
# GBP_USD 0
